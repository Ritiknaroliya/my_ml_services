# %%
# Online retail dataset analysis of identifying cancelled orders,
# analysis on quantitative data,
# calculate the percentage of cancelled orders,
# get the number of customer country  wise

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load the Dataset

# %%
retail_df = pd.read_excel("C:\\Users\\Ritik_Naroliya\\Downloads\\Online Retail.xlsx")
# shape of our dataset
print("The shape of our dataset is: ", retail_df.shape)
# Out:
# The shape of our dataset is:  (541909, 8)

# %%
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Exploring dataset

# %%
# Exploring the unique values of each attribute
print("Number of transaction:", retail_df['InvoiceNo'].nunique())
print("Number of products:", retail_df['StockCode'].nunique())
print("Number of customers:", retail_df['CustomerID'].nunique())
print("Number of countries:", retail_df['Country'].nunique())
# Out:
# Number of transaction: 25900
# Number of products: 4070
# Number of customers: 4372
# Number of countries: 38

# %%
# Determine the percentage of customer with null id
print("Percentage of customer NA:", round(retail_df['CustomerID'].isnull().sum() *100 / len(retail_df),2), "%")
# Out:
# Percentage of customer NA: 24.93 %

# %%
# Analysis the quantitative data
retail_df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# Determine the percentage of cancelled orders

# %%
cancelled_orders = retail_df[retail_df['InvoiceNo'].astype(str).str.contains('c')]
cancelled_orders.head()

# search for transaction where quantity == -80995
cancelled_orders[cancelled_orders['Quantity']==-80995]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
# Group the customers by country

# %%
print("We have", len(cancelled_orders), "cancelled_orders.")
# Out:
# We have 0 cancelled_orders.

# %%
# Analyse country with more customers

# %%
# Customer by country
retail_df['total_cost'] = retail_df['Quantity'] * retail_df['UnitPrice']
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_cost
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %%
retail_df.groupby('Country').sum().sort_values(by='total_cost', ascending=False)
# Out:
# C:\Users\Ritik_Naroliya\AppData\Local\Temp\ipykernel_57584\2896196185.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   retail_df.groupby('Country').sum().sort_values(by='total_cost', ascending=False)
#                       Quantity    UnitPrice    CustomerID   total_cost
# Country
# United Kingdom         4263829  2245715.474  5.626433e+09  8187806.364
# Netherlands             200128     6492.550  3.419054e+07   284661.540
# EIRE                    142637    48447.190  1.103917e+08   263276.820
# Germany                 117448    37666.000  1.200751e+08   221698.210
# France                  110480    43031.990  1.076489e+08   197403.900
# Australia                83653     4054.750  1.569300e+07   137077.270
# Switzerland              30325     6813.690  2.377592e+07    56385.350
# ...
